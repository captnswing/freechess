# %%
from freechess.pgnparser import parse_pgn, process_pgnfile

# %%
import pandas as pd

# %%
pd.DataFrame(parse_pgn(open('freechess/fixtures/eboard.pgn').read()))
# Out:
#           black blackelo        date                  event  \
# 0    captnswing      961  2004.11.27  ICS Rated Chess Match
# 1   alexcardoso      887  2004.11.27  ICS Rated Chess Match
# 2    captnswing      965  2004.11.27  ICS Rated Chess Match
# 3      honkyboy     1032  2004.11.27  ICS Rated Chess Match
# 4   alexcardoso      887  2004.11.27  ICS Rated Chess Match
# 5    captnswing      983  2004.11.27  ICS Rated Chess Match
# 6   alexcardoso      887  2004.11.27  ICS Rated Chess Match
# 7        maucsc      990  2004.11.27  ICS Rated Chess Match
# 8    captnswing      988  2004.11.27  ICS Rated Chess Match
# 9    captnswing      997  2004.11.27  ICS Rated Chess Match
# 10       Edsmyr      981  2004.11.27  ICS Rated Chess Match
# 11   captnswing     1003  2004.11.27  ICS Rated Chess Match
# 12       Edsmyr      966  2004.11.27  ICS Rated Chess Match
# 13   captnswing     1001  2004.11.27  ICS Rated Chess Match
#
# ...

# %%
pd.DataFrame(process_pgnfile('freechess/fixtures/eboard.pgn'))
# Out:
#           date  opponent_elo opponent_name   result  self_elo self_white  \
# 0   2004-11-27           741     TheMirage      0-1       961      False
# 1   2004-11-27          1005        gjmata      0-1       965      False
# 2   2004-11-27          1032      honkyboy      1-0       974       True
# 3   2004-11-27           934      RainFall      1-0       983      False
# 4   2004-11-27           887   alexcardoso      1-0       965       True
# 5   2004-11-27           990        maucsc      1-0       980       True
# 6   2004-11-27          1053        sjames      0-1       988      False
# 7   2004-11-27           929        blerim  1/2-1/2       997      False
# 8   2004-11-27           981        Edsmyr      1-0       995       True
# 9   2004-11-27           973        Edsmyr      0-1      1003      False
# 10  2004-11-27           966        Edsmyr      0-1      1010       True
# 11  2004-11-27          1063        Carita      1-0      1001      False
#
#    timecontrol
# ...
